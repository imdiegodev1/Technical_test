# %%
import pandas as pd

# %% [markdown]
# Para la lectura de base de datos se debe especificar el tipo de motor pues el tipo de archivo no esta entre las opciones estandar de la libreria pandas

# %%
#BD
df_avianca = pd.read_excel('./BD.xlsb', engine= 'pyxlsb', sheet_name='Capacity Tracking')

# %%
df_avianca.head(5)
# Out:
#       Date code_dep code_arr carrier equip operation_type Ciudad Origen  \
# 0  2019011      AGT      SCL      GG   74Y        Charter           AGT
# 1  2019011      AMS      ATL      DL   333        Charter           AMS
# 2  2019011      AMS      ATL      DL   333      Scheduled           AMS
# 3  2019011      AMS      ATL      DL   77L      Scheduled           AMS
# 4  2019011      AMS      ATL      KL   77E      Scheduled           AMS
#
#   Ciudad Destino carrier name      weight_kg    volume_m3       atk  \
# 0            SCL        1SKGO  324192.000000  2250.000000  575190.0
# 1            ATL        2DEES   21514.000000   148.000000  152374.0
# 2            ATL        2DEES   53786.666667   371.666667  380935.0
# 3            ATL        2DEES   28346.000000   196.000000  200750.0
# 4            ATL        3KLLM   54488.000000   377.600000  385896.0
#
#    frequency  block_hours
# 0          3     6.000000
# 1          2    20.000000
# 2          5    45.833333
# ...

# %%
#Maestros
m_regiones = pd.read_excel('./BD.xlsb', engine= 'pyxlsb', sheet_name='Maestro Regiones')
m_aircraft = pd.read_excel('./BD.xlsb', engine= 'pyxlsb', sheet_name='Maestro Aircraft')

# %% [markdown]
# # Revisión bd

# %%
df_avianca.shape
# Out:
# (393257, 14)

# %%
df_avianca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 393257 entries, 0 to 393256
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Date            393257 non-null  int64
#  1   code_dep        393257 non-null  object
#  2   code_arr        393257 non-null  object
#  3   carrier         393257 non-null  object
#  4   equip           393257 non-null  object
#  5   operation_type  393257 non-null  object
#  6   Ciudad Origen   393257 non-null  object
#  7   Ciudad Destino  393257 non-null  object
#  8   carrier name    388163 non-null  object
#  9   weight_kg       393257 non-null  float64
#  10  volume_m3       393257 non-null  float64
#  11  atk             393257 non-null  float64
#  12  frequency       393257 non-null  int64
#  13  block_hours     393257 non-null  float64
# dtypes: float64(4), int64(2), object(8)
# memory usage: 42.0+ MB

# %% [markdown]
# Haciendo un recorrido preliminar de la base de datos aparentemente esta completa. En este punto es dificil decidir si se deben o no eliminar columnas o filas por lo cual lo mejor es cruzar la información con los maestros proporcionados y que es posible eliminar (columnas y/o regitros incompletos que generen ruido)

# %% [markdown]
# # Feature Engineering

# %%
##Renombre de columnas para faciltar manipulación (las columnas en una bd no deberian tener espacios).
df_avianca.rename(columns={'Ciudad Origen': 'Ciudad_Origen', 
                           'Ciudad Destino': 'Ciudad_Destino',
                           'carrier name': 'carrier_name'}, inplace = True)

df_avianca.columns
# Out:
# Index(['Date', 'code_dep', 'code_arr', 'carrier', 'equip', 'operation_type',
#        'Ciudad_Origen', 'Ciudad_Destino', 'carrier_name', 'weight_kg',
#        'volume_m3', 'atk', 'frequency', 'block_hours'],
#       dtype='object')

# %%
#cruzar base con maestro regiones (departure)
m_regiones_merge = m_regiones[['Airport_Code', 'Airport_Name', 'City_Name', 'Country_Name', 'Region_Name']]

df_info_dep = df_avianca.merge(m_regiones_merge, left_on='code_dep', right_on='Airport_Code')

df_info_dep.rename(columns={'Airport_Name': 'Airport_Name_dep', 
                           'City_Name': 'City_Name_dep',
                           'Country_Name': 'Country_Name_dep',
                           'Region_Name': 'Region_Name_dep'}, inplace = True)
df_info_dep = df_info_dep.drop(['code_dep', 'Airport_Code'], axis=1)

# %%
#cruzar base con maestro regiones (arrive)
df_info_arr = df_info_dep.merge(m_regiones_merge, left_on='code_arr', right_on='Airport_Code')

df_info_arr.rename(columns={'Airport_Name': 'Airport_Name_arr', 
                           'City_Name': 'City_Name_arr',
                           'Country_Name': 'Country_Name_arr',
                           'Region_Name': 'Region_Name_arr'}, inplace = True)
df_info_places = df_info_arr.drop(['code_arr', 'Airport_Code'], axis=1)


df_info_places.columns
# Out:
# Index(['Date', 'carrier', 'equip', 'operation_type', 'Ciudad_Origen',
#        'Ciudad_Destino', 'carrier_name', 'weight_kg', 'volume_m3', 'atk',
#        'frequency', 'block_hours', 'Airport_Name_dep', 'City_Name_dep',
#        'Country_Name_dep', 'Region_Name_dep', 'Airport_Name_arr',
#        'City_Name_arr', 'Country_Name_arr', 'Region_Name_arr'],
#       dtype='object')

# %%
m_aircraft_merge = m_aircraft[['equip', 'aircraft_type', 'aircraft_full_name']]

df_final = df_info_places.merge(m_aircraft_merge, left_on='equip', right_on='equip')

df_final = df_final.drop(['equip'], axis=1)

# %%
df_final.columns
# Out:
# Index(['Date', 'carrier', 'operation_type', 'Ciudad_Origen', 'Ciudad_Destino',
#        'carrier_name', 'weight_kg', 'volume_m3', 'atk', 'frequency',
#        'block_hours', 'Airport_Name_dep', 'City_Name_dep', 'Country_Name_dep',
#        'Region_Name_dep', 'Airport_Name_arr', 'City_Name_arr',
#        'Country_Name_arr', 'Region_Name_arr', 'aircraft_type',
#        'aircraft_full_name'],
#       dtype='object')

# %%
df_final.head(5)
# Out:
#       Date carrier operation_type Ciudad_Origen Ciudad_Destino carrier_name  \
# 0  2019011      GG        Charter           AGT            SCL        1SKGO
# 1  2019017      GG      Scheduled           AGT            SCL        1SKGO
# 2  2019031      GG      Scheduled           AGT            SCL        1SKGO
# 3  2019041      GG        Charter           AGT            SCL        1SKGO
# 4  2019041      GG      Scheduled           AGT            SCL        1SKGO
#
#    weight_kg  volume_m3       atk  frequency  ...  Airport_Name_dep  \
# 0   324192.0     2250.0  575190.0          3  ...      Guarani Intl
# 1   216128.0     1500.0  383460.0          2  ...      Guarani Intl
# 2   216128.0     1500.0  383460.0          2  ...      Guarani Intl
# 3   216128.0     1500.0  383460.0          2  ...      Guarani Intl
# 4   108064.0      750.0  191730.0          1  ...      Guarani Intl
#
#      City_Name_dep Country_Name_dep Region_Name_dep       Airport_Name_arr  \
# ...

# %%
ciudades_origen = df_final.Ciudad_Origen.unique()
ciudades_destino = df_final.Ciudad_Destino.unique()
tipos_operacion = df_final.operation_type.unique()
regiones_dep = df_final.Region_Name_dep.unique()
regiones_arr = df_final.Region_Name_arr.unique()
pais_dep = df_final.Country_Name_dep.unique()
pais_arr = df_final.Country_Name_arr.unique()
tipos_aviones = df_final.aircraft_full_name.unique()

print(f'''Se analizan el numero de elementos que hay por cada una de las caracteristicas que se cree son mas
relevantes obteniendo: 
        - Ciudades origen: {len(ciudades_origen)}
        - Ciudades destino: {len(ciudades_destino)}
        - Tipos operación: {len(tipos_operacion)}
        - Paices de salida: {len(pais_dep)}
        - Paices de llegada: {len(pais_arr)}
        - Regiones de salida: {len(regiones_dep)}
        - Regiones de llegada: {len(regiones_arr)}
        - Tipos de aviones: {len(tipos_aviones)}''')
# Out:
# Se analizan el numero de elementos que hay por cada una de las caracteristicas que se cree son mas
# relevantes obteniendo:
#         - Ciudades origen: 1011
#         - Ciudades destino: 1022
#         - Tipos operación: 4
#         - Paices de salida: 91
#         - Paices de llegada: 90
#         - Regiones de salida: 8
#         - Regiones de llegada: 8
#         - Tipos de aviones: 59

# %%
#Obtener año y mes
df_final['Date'] = df_final['Date'].astype(str)
df_final['año'] = df_final['Date'].str.slice(0, 4).astype(int)
df_final['mes'] = df_final['Date'].str.slice(4, 6).astype(int)
df_final['dia_semana'] = df_final['Date'].str.slice(6, 7).astype(int)

df = df_final.drop(['Date'], axis=1)
df.columns
# Out:
# Index(['carrier', 'operation_type', 'Ciudad_Origen', 'Ciudad_Destino',
#        'carrier_name', 'weight_kg', 'volume_m3', 'atk', 'frequency',
#        'block_hours', 'Airport_Name_dep', 'City_Name_dep', 'Country_Name_dep',
#        'Region_Name_dep', 'Airport_Name_arr', 'City_Name_arr',
#        'Country_Name_arr', 'Region_Name_arr', 'aircraft_type',
#        'aircraft_full_name', 'año', 'mes', 'dia_semana'],
#       dtype='object')

# %%
##Evaluación de correlación entre variables para posible descarte de camos con una correlación estrecha
corrM = df.corr()
corrM
# Out:
#              weight_kg  volume_m3       atk  frequency  block_hours       año  \
# weight_kg     1.000000   0.999999  0.837820   0.377093     0.221523  0.063440
# volume_m3     0.999999   1.000000  0.837759   0.376357     0.220796  0.063612
# atk           0.837820   0.837759  1.000000   0.359521     0.430649  0.026515
# frequency     0.377093   0.376357  0.359521   1.000000     0.822721 -0.136069
# block_hours   0.221523   0.220796  0.430649   0.822721     1.000000 -0.189268
# año           0.063440   0.063612  0.026515  -0.136069    -0.189268  1.000000
# mes           0.007696   0.007681  0.008907   0.011418     0.009178 -0.258337
# dia_semana    0.027180   0.027148  0.036689   0.021671     0.042635 -0.000424
#
#                   mes  dia_semana
# weight_kg    0.007696    0.027180
# volume_m3    0.007681    0.027148
# atk          0.008907    0.036689
# frequency    0.011418    0.021671
# block_hours  0.009178    0.042635
# año         -0.258337   -0.000424
# ...

# %% [markdown]
# Hay una fuerte correlación entre peso (weight_kg), volumen (volume_m3) y capacidad toneladas (atk) por lo cual más adelante se decidira cual de los campos es relevante mantener y cuales descartar para el análisis.

# %% [markdown]
# Debido a que es pertinente un análisis de la capacidad de carga se debe entonces analizar por algun tipo de variable relacionada con este aspecto. Como ya vimos anteriormente el peso y volumen estan estrechamente correlacionados. Se asumira entonces que la variable pertinente para analizar la capacidad de carga sera el peso (weight_kg).
#
# Para continuar con el proceso de feature engineering se creara una variable categorica del peso para simplificar el análisis.

# %%
df['weight_kg'].describe()
# Out:
# count    3.932570e+05
# mean     8.043905e+04
# std      9.965315e+04
# min      0.000000e+00
# 25%      2.687667e+04
# 50%      5.134200e+04
# 75%      8.812500e+04
# max      1.489940e+06
# Name: weight_kg, dtype: float64

# %% [markdown]
# - Peso minimo 0 kg.
# - peso maximo 1'489.940 kg.

# %%
df_test = df[df['weight_kg'] > 1]
df_test['weight_kg'].count()
# Out:
# 392079

# %%
##Ya que estamos analisando la capacidad de carga, aquellos casos con carga menor a 1 no seran relevantes en el análisis.
df = df[df['weight_kg'] > 1]

# %% [markdown]
# Para efectos practicos la variable peso se dividira en 4 intervalos:
# - (3, 93.121)
# - (93.122, 186.242)
# - (186.243, 279.363)
# - (279.364, 372.848)

# %% [markdown]
# estadisticamente se entiende que el numero de intervalos ideal en este caso debe ser n_datos^(1/3) siendo n_datos > 200 y n_datos = numero de registros , sin embargo se hace esta simplificación para mayor practicidad a la hora de generar un análisis enfocado a personal no técnico.
#
# Ahora bien, la razon por la cual se hacen intervalos solo entre los 3 y 372.485 kg es porque como veremos más adelante más del 75% de los registros se encuentran entre los pesos de 3 a 372.485. Para ilustrar mejor esto nos remitimos a la siguiente grafica:

# %%
def f_intervalos(x):
    
    if x < 372486:
        return '(3, 372.485)'
    elif x >= 372486 and x < 744971:
        return '(372.486, 744.970)'
    elif x >= 744970 and x < 1117456:
        return "(744.971, 1'117.455)"
    else:
        return "(1'117.456, 1'489.940)"

df['weight_kg_cat'] = df['weight_kg'].apply(f_intervalos)

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=df, x='weight_kg_cat')
plt.show()

# %% [markdown]
# En este caso se utilizaron los siguientes intervalos:
# - (3, 372.485)
# - (372.486, 744.970)
# - (744.971, 1'117.455)
# - (1'117.456, 1'489.940)
#
# Y como es claro la base o puede tener errores en los pesos o la empresa se especializa en transportes menores a loas 372.485 kg.

# %%
def f_intervalos(x):
    
    if x < 93121:
        return '(3, 93.121)'
    elif x >= 93121 and x < 186243:
        return '(93.122, 186.242)'
    elif x >= 186243 and x < 279346:
        return "(186.243, 279.363)"
    else:
        return "(279.364, 372.848)"

df['weight_kg_cat'] = df['weight_kg'].apply(f_intervalos)

# %% [markdown]
# Para análisis graficos se agrega una variable count

# %%
df['count'] = 1

# %%
df['weight_kg_cat'].unique()
# Out:
# array(['(279.364, 372.848)', '(186.243, 279.363)', '(93.122, 186.242)',
#        '(3, 93.121)'], dtype=object)

# %% [markdown]
# Con este nuevo intervalo demostramos entonces en la siguiente grafica una distribución aunque no ideal pero mucho mejor que con el intervalo anteriormente mencionado

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=df, x='weight_kg_cat')
plt.show()

# %% [markdown]
# Para el futuro análisis de la interacción entre regiones se peude desarrollar un atributo que concatene la region de salida y llegada

# %%
df['region_interaction'] = df['Region_Name_dep']+'-'+df['Region_Name_arr']

# %% [markdown]
# # Filtro BD

# %%
#Identificar outliers de peso (weight_kg), columen (volume_m3), frecuencia (frequency),
#horas de trabajo o horas bloque (block_hours)

##Se evaluaran los outliers por tipo de opeeración

import seaborn as sns
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,8))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
ax = fig.add_subplot(2, 2, 1)
sns.boxplot( x=df["operation_type"], y=df["weight_kg"])
ax = fig.add_subplot(2, 2, 2)
sns.boxplot( x=df["operation_type"], y=df["volume_m3"])
ax = fig.add_subplot(2, 2, 3)
sns.boxplot( x=df["operation_type"], y=df["frequency"]);
ax = fig.add_subplot(2, 2, 4)
sns.boxplot( x=df["operation_type"], y=df["block_hours"]);
plt.show()

# %%
##HAy una relacion directa entre el peso (wight_kg) y volumen (colume_m3) por lo cual solo se filtraran los outliers
##encontrados dentro del campo peso con el fin de simplifcar el proceso

df_scheduled_h = df[df['operation_type'] == 'Scheduled']
q_height_bhours_scheduled = df_scheduled_h['block_hours'].quantile(0.90)

df_otros_ops_type = df[df['operation_type'] != 'Scheduled']
q_height_hours = df_otros_ops_type['block_hours'].quantile(0.98)

q_height_weight = df['weight_kg'].quantile(0.75)

##Remover outliers peso
df_filtter = df[df['weight_kg'] < q_height_weight]

##Remover outliers horas bloque de scheduled
df_filtter = df_filtter[(df_filtter['block_hours'] < q_height_bhours_scheduled) | (df['operation_type'] == 'Scheduled')]

##Remover outliers horas bloque de todos menos scheduled
df_filtered = df_filtter[(df_filtter['block_hours'] < q_height_hours) | (df['operation_type'] != 'Scheduled')]


#q_high_weight = df['weight_kg'].quantile(0.75)
#q_high_hours = df['block_hours'].quantile(0.75)
#
#print(q_high_weight)
#print(q_high_hours)
# Out:
# <ipython-input-182-9285e5157ae9>:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_filtter = df_filtter[(df_filtter['block_hours'] < q_height_bhours_scheduled) | (df['operation_type'] == 'Scheduled')]
# <ipython-input-182-9285e5157ae9>:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_filtered = df_filtter[(df_filtter['block_hours'] < q_height_hours) | (df['operation_type'] != 'Scheduled')]

# %%
fig = plt.figure(figsize=(15,8))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
ax = fig.add_subplot(2, 2, 1)
sns.boxplot( x=df_filtered["operation_type"], y=df_filtered["weight_kg"])
ax = fig.add_subplot(2, 2, 2)
sns.boxplot( x=df_filtered["operation_type"], y=df_filtered["volume_m3"])
ax = fig.add_subplot(2, 2, 3)
sns.boxplot( x=df_filtered["operation_type"], y=df_filtered["frequency"]);
ax = fig.add_subplot(2, 2, 4)
sns.boxplot( x=df_filtered["operation_type"], y=df_filtered["block_hours"]);
plt.show()

# %% [markdown]
# Es evidente la reducción de los outliers que se presentan solo con filtrar bajo los 3 parametros indicados anteriormente.

# %% [markdown]
# # Análisis

# %% [markdown]
# ## 1. Impacto de la Pandemia en la Capacidad de Carga Aérea

# %% [markdown]
# Gráficas de disperción entre las diferentes variables numericas para exploración de patrones.

# %%
pd.plotting.scatter_matrix(df_filtered, figsize  = [10, 10])
# Out:
# c:\users\diego\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_matplotlib\misc.py:89: UserWarning: Attempting to set identical left == right == 1.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# c:\users\diego\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_matplotlib\misc.py:90: UserWarning: Attempting to set identical bottom == top == 1.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# c:\users\diego\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_matplotlib\misc.py:80: UserWarning: Attempting to set identical left == right == 1.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[i])
# array([[<AxesSubplot:xlabel='weight_kg', ylabel='weight_kg'>,
#         <AxesSubplot:xlabel='volume_m3', ylabel='weight_kg'>,
# ...

# %%
df_filtered.columns
# Out:
# Index(['carrier', 'operation_type', 'Ciudad_Origen', 'Ciudad_Destino',
#        'carrier_name', 'weight_kg', 'volume_m3', 'atk', 'frequency',
#        'block_hours', 'Airport_Name_dep', 'City_Name_dep', 'Country_Name_dep',
#        'Region_Name_dep', 'Airport_Name_arr', 'City_Name_arr',
#        'Country_Name_arr', 'Region_Name_arr', 'aircraft_type',
#        'aircraft_full_name', 'año', 'mes', 'dia_semana', 'weight_kg_cat',
#        'count'],
#       dtype='object')

# %%
df_filtered_2019 = df[df['año'] == 2019]
df_filtered_2020 = df[df['año'] == 2020]
df_filtered_2021 = df[df['año'] == 2021]

# %% [markdown]
# analisemos ahora a grandes rasgos la capacidad de carga:A grandes rasgos la capacidad de carga se vio afectada de la siguiente manera:

# %%
fig = plt.figure(figsize=(15,10))
fig.subplots_adjust(hspace=0.6, wspace=0.2)
ax=fig.add_subplot(2,2,1)
sns.histplot(data=df_filtered_2019, x='weight_kg_cat').set(title='2019')
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)
ax=fig.add_subplot(2,2,2)
sns.histplot(data=df_filtered_2020, x='weight_kg_cat').set(title='2020')
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)
ax=fig.add_subplot(2,2,3)
sns.histplot(data=df_filtered_2021, x='weight_kg_cat').set(title='2021')
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)
plt.show()

# %% [markdown]
# Se peude apreciar muy claramente como durante el 2020 (pandemia) disminuyo a casi la mitad la capacidad de carga por año. De cualquier forma teniendo en cuenta que del año 2021 solo se tienen 7 meses para tranquilidad de la compañia su capacidad a ido aumentando y posiblemente llegue a los valores acostuumbrados antes de la pandemia.
#
# Es evidente ver tambien un aumento conciderable del transporte de carga de viajes con capacidad de entre 93122 y 186242 kg.

# %% [markdown]
# ### Impacto por tipo de aeronave

# %%
df_n_vuelos = df_filtered[['aircraft_type', 'operation_type', 'año', 'mes', 'count']]
df_n_vuelos = df_n_vuelos.groupby(by=['aircraft_type', 'operation_type', 'año', 'mes']).count().reset_index()

df_n_vuelos = df_n_vuelos.sort_values(by=['año', 'count'], ascending=False)

# %%
df_n_vuelos_top = df_n_vuelos.set_index(['aircraft_type']).groupby(['mes', 'año', 'operation_type'])['count'].nlargest(3).reset_index()
df_n_vuelos_top
# Out:
#      mes   año operation_type aircraft_type  count
# 0      1  2019        Charter         B767F    312
# 1      1  2019        Charter          B767    272
# 2      1  2019        Charter          A330    203
# 3      1  2019   Part Charter          B767     10
# 4      1  2019   Part Charter          B777      8
# ..   ...   ...            ...           ...    ...
# 280   12  2020   Part Charter          B777      7
# 281   12  2020   Part Charter          A330      3
# 282   12  2020      Scheduled          B787   1091
# 283   12  2020      Scheduled          A330    714
# 284   12  2020      Scheduled          B777    620
#
# [285 rows x 5 columns]

# %%
df_n_vuelos_top_2019 = df_n_vuelos_top[df_n_vuelos_top['año']==2019]
df_n_vuelos_top_2020 = df_n_vuelos_top[df_n_vuelos_top['año']==2020]
df_n_vuelos_top_2021 = df_n_vuelos_top[df_n_vuelos_top['año']==2021]

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='mes', y='count', hue='aircraft_type', data=df_n_vuelos_top_2019, ci=None).set(title='2019')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='mes', y='count', hue='aircraft_type', data=df_n_vuelos_top_2020, ci=None).set(title='2020')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='mes', y='count', hue='aircraft_type', data=df_n_vuelos_top_2021, ci=None).set(title='2021')
plt.show()

# %% [markdown]
# Tal como se vió en el análisis a grandes rasgos de transporte de carga por peso a lo largo del 2019, 2020 y los datos que se tienen del 2021, los viajes se han ido recuperando a lo largo de este último año.
#
# Es claro ver que la aeronave B787 utualmente tiene la mayor frecuencia de viajes junto con la aeronave A330. Cada una tiene en total 67.303 y 69.250 viajes acumulados respectivamente.

# %% [markdown]
# ### Impacto transporte entre regiones

# %%
df.columns
# Out:
# Index(['carrier', 'operation_type', 'Ciudad_Origen', 'Ciudad_Destino',
#        'carrier_name', 'weight_kg', 'volume_m3', 'atk', 'frequency',
#        'block_hours', 'Airport_Name_dep', 'City_Name_dep', 'Country_Name_dep',
#        'Region_Name_dep', 'Airport_Name_arr', 'City_Name_arr',
#        'Country_Name_arr', 'Region_Name_arr', 'aircraft_type',
#        'aircraft_full_name', 'año', 'mes', 'dia_semana', 'weight_kg_cat',
#        'count', 'region_interaction'],
#       dtype='object')

# %%
df_regions_depp = df[['Region_Name_dep', 'count', 'año']]
df_regions_depp = df_regions_depp.groupby(['Region_Name_dep', 'año']).count().reset_index()

plt.figure(figsize=(15,8))
sns.barplot(x='Region_Name_dep', y='count', hue='año', data=df_regions_depp, ci=None). set (title = ' Evolución regiones ')
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)
plt.show()

# %% [markdown]
# Esta gráfica de barras nos permite apreciar nuevamente la tendencia de recuperación de la operación de avianca, en este caso con todas las regiones ocmo se puede apreciar. Aunque no es una región con una participación muy amplia, las interacciones con Mexico pueden crecer en lo que se lleva del año 2021. Evidentemente las regiones más afectadas son Southern Europe y North America. En el caso de Southern Europe la recuperación no se ve tan favorable. Caso contrario con las interacciones que hay con North America.

# %%
df_regiones_mes_2020 = df_filtered_2020[['Region_Name_dep', 'count', 'mes']]
df_regiones_mes_2020 = df_regiones_mes_2020.groupby(['Region_Name_dep', 'mes']).count().reset_index()

plt.figure(figsize=(15,8))
sns.barplot(x='Region_Name_dep', y='count', hue='mes', data=df_regiones_mes_2020, ci=None). set (title = ' Evolución mensual año 2020 regiones ')
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)
plt.show()

# %% [markdown]
# Es evidente como fue afectado el transporte a las diferentes regiones. Para el mes de Abril cuando todo el mundo cerro sus fronteras en algunos casos se llego a disminuir el transporte de mercancia a menos de la mitad. Aunque hay algunas regiones que mostraron una buena recuperación para final del año 2020. En este caso vemos que las regiones con peor recuperación han sido Northern Europe y  Southern Europe mientras que las regiones de Eastern Europe, South America y North America han mostrado una muy buena recuperación.

# %%
df_regions_depp = df[['Region_Name_dep', 'weight_kg', 'año']]
df_regions_depp = df_regions_depp.groupby(['Region_Name_dep', 'año']).mean().reset_index()

plt.figure(figsize=(15,8))
sns.barplot(x='Region_Name_dep', y='weight_kg', hue='año', data=df_regions_depp, ci=None). set (title = ' Evolución peso promedio transportado por region y año ')
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)
plt.show()

# %% [markdown]
# Al ver esta grafica podemos observar una mejora año a año con respecto a los pesos promedios transportados. Esto lo que quiere decir es que se ha vuelto más eficiente el transporte. Se debe observar detenidamente las regioens de Eastern Europe y Mexico pues demuestran lo contrario y como se vio anteriormente son 2 de las regiones que demuestran una buena recuperación.

# %%
df_region_interaction = df_filtered[['region_interaction', 'año', 'mes', 'count']]
df_region_interaction = df_region_interaction.groupby(by=['region_interaction', 'año', 'mes']).count().reset_index()

df_region_interaction = df_region_interaction.sort_values(by=['año', 'count'], ascending=False)

df_region_interaction = df_region_interaction.set_index(['region_interaction']).groupby(['mes', 'año'])['count'].nlargest(1).reset_index()

df_region_interaction_2019 = df_region_interaction[df_region_interaction['año'] == 2019].sort_values(by='count', ascending=False)
df_region_interaction_2020 = df_region_interaction[df_region_interaction['año'] == 2020].sort_values(by='count', ascending=False)
df_region_interaction_2021 = df_region_interaction[df_region_interaction['año'] == 2021].sort_values(by='count', ascending=False)

df_region_interaction_top = pd.concat([df_region_interaction_2019.head(3), df_region_interaction_2020.head(3), df_region_interaction_2021.head(3)])
df_region_interaction_top.set_index("año")
# Out:
#       mes            region_interaction  count
# año
# 2019   10  North America-Western Europe   1191
# 2019    6  North America-Western Europe    979
# 2019    9  North America-Western Europe    948
# 2020    3  North America-Western Europe   1265
# 2020    2   South America-South America    827
# 2020    1   South America-South America    826
# 2021    1   South America-South America    648
# 2021    2   South America-South America    640
# 2021    4   South America-South America    634

# %% [markdown]
# en esta grafica podemos ver las top 3 interacciones entre regiones para cada año y mes. Como vemos antes del 2020 el transporte entre las regiones North America y Western Europe era primordial. Para el 2020 cuando la emergencia sanitaria empezo vemos que la tendencia es ahora transporte entre la misma region de South America.

# %% [markdown]
# ### Países más afectados

# %%
df_filtered.columns
# Out:
# Index(['carrier', 'operation_type', 'Ciudad_Origen', 'Ciudad_Destino',
#        'carrier_name', 'weight_kg', 'volume_m3', 'atk', 'frequency',
#        'block_hours', 'Airport_Name_dep', 'City_Name_dep', 'Country_Name_dep',
#        'Region_Name_dep', 'Airport_Name_arr', 'City_Name_arr',
#        'Country_Name_arr', 'Region_Name_arr', 'aircraft_type',
#        'aircraft_full_name', 'año', 'mes', 'dia_semana', 'weight_kg_cat',
#        'count', 'region_interaction'],
#       dtype='object')

# %%
df_pais = df_filtered[['Country_Name_dep', 'año', 'mes', 'count']]
df_pais = df_pais.groupby(by=['Country_Name_dep', 'año', 'mes']).count().reset_index()

df_pais = df_pais.sort_values(by=['año', 'count'], ascending=False)

df_pais = df_pais.set_index(['Country_Name_dep']).groupby(['mes', 'año'])['count'].nlargest(3).reset_index()

df_pais_2019 = df_pais[df_pais['año'] == 2019].sort_values(by='count', ascending=False)
df_pais_2020 = df_pais[df_pais['año'] == 2020].sort_values(by='count', ascending=False)
df_pais_2021 = df_pais[df_pais['año'] == 2021].sort_values(by='count', ascending=False)

df_pais_top = pd.concat([df_pais_2019.head(3), df_pais_2020.head(3), df_pais_2021.head(3)])

# %%
fig = plt.figure(figsize=(15,10))
fig.subplots_adjust(hspace=0.4, wspace=0.2)
ax=fig.add_subplot(2,2,1)
sns.barplot(x='mes', y='count', hue='Country_Name_dep', data=df_pais_2019, ci=None).set(title='2019')
locs, labels = plt.xticks()
ax=fig.add_subplot(2,2,2)
sns.barplot(x='mes', y='count', hue='Country_Name_dep', data=df_pais_2020, ci=None).set(title='2020')
locs, labels = plt.xticks()
ax=fig.add_subplot(2,2,3)
sns.barplot(x='mes', y='count', hue='Country_Name_dep', data=df_pais_2021, ci=None).set(title='2021')
locs, labels = plt.xticks()
plt.show()

# %% [markdown]
# Como podemos ver, el tiempo pre'pandemia Avianca tenía más países en su top 3. Entre ellos estaba el Reino Unido, Francia y Canada. Despues de empezar la pandemia y seguro debido a su reestructuración su mercado clarmente se redujo y los paices top 3 por mes ahora tienen a ser solo Mexico, Brasil y Estados Unidos. Aunque es claro como se ha ido recuperando el numero de vuelosde su operación se ha limitado. Estados unidos aunque ha sido el país que más vuelos de salida ha mostrado en todo momento, no ha logrado tener los mismos numeros previos a la emergencia sanitaria.

# %% [markdown]
# ### Impacto apra Avianca Cargo

# %% [markdown]
# - Como es evidente, a partir de abril del 2020 la operación de Avianca Cargo se vio fuertemente afectada por la pandemia. Igualmente es evidente ver como han aumentado sus esfuerzos para ser más eficientes en la capacidad de carga que mantiene su operación.
# - Como vimos en el último análisis, los países donde frecuentaban despegar han cambiado y ahora se centran más en la región. Comportamiento que pueden aprovechar y potenciar para diferentes áreas de negocio.
# - Su presencia en la region puede apalancarlos para volver a tener una participación significativa a otras regiones como Europa y Norte America.

# %% [markdown]
# ## 2. Análisis Top 3 rutas

# %% [markdown]
# Como se vió previamente, las rutas dentro de la región South America han sido las más importantes despues del comienzo de la emergencia sanitaria. Razon por la cual nos centraremos en esta región y más exactamente en los países de Mexico, Brasil. Debido a que Estados unidos es un lugar de partida muy importante tambien se tendra en cuenta para este análisis.

# %%
df_2 = df_filtered[df_filtered['region_interaction'] == 'South America-South America']
df_2 = df_2[(df_2['Country_Name_dep'] == 'UNITED STATES')| (df_2['Country_Name_dep'] == 'MEXICO') | (df_2['Country_Name_dep'] == 'BRAZIL')]

df_2
# Out:
#        carrier operation_type Ciudad_Origen Ciudad_Destino carrier_name  \
# 18937       UC        Charter           BSB            SCL       14LAAM
# 18938       UC        Charter           BSB            SCL       14LAAM
# 18939       UC        Charter           CWB            SCL       14LAAM
# 18941       UC        Charter           CWB            SCL       14LAAM
# 18942       UC      Scheduled           CWB            SCL       14LAAM
# ...        ...            ...           ...            ...          ...
# 371999     UKL        Charter           JPA            SJK      144UKCE
# 372000      M9        Charter           CMP            SJK      232MOES
# 372713     2L!        Charter           RIO            CCS      100TAES
# 373179     2L!        Charter           MAO            CBB      100TAES
# 373281     2L!        Charter           RIO            LPB      100TAES
#
#         weight_kg  volume_m3       atk  frequency  block_hours  ...  \
# ...

# %%
df_2['country_interaction'] = df_2['Country_Name_dep']+'-'+df_2['Country_Name_arr']

# %%
df_top = df_2[['country_interaction', 'año', 'mes', 'count']]
df_top = df_top.groupby(by=['country_interaction', 'año', 'mes']).count().reset_index()

df_top = df_top.sort_values(by=['año', 'count'], ascending=False)

df_top = df_top.set_index(['country_interaction']).groupby(['mes', 'año'])['count'].nlargest(3).reset_index()

df_top.sort_values(by='count', ascending=False)

df_top_sum = df_top.groupby('country_interaction')['count'].sum()
df_top_sum.sort_values(ascending=False)
# Out:
# country_interaction
# BRAZIL-BRAZIL       4905
# BRAZIL-COLOMBIA      840
# BRAZIL-CHILE         739
# BRAZIL-ARGENTINA     216
# BRAZIL-ECUADOR        28
# BRAZIL-PERU            8
# Name: count, dtype: int64

# %% [markdown]
# Seleccionando los top 3 transportes mes a mes encontramos que hay las principales interacciones son entre Brazil - Brazil, Brazil - Colombia y Brazil - Chile. De estas entonces vale la pena seleccionar el caso más frecuente y evaluar su eficiencia.

# %%
sns.histplot(data=df_top, x="country_interaction", hue='año', multiple="stack")
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)
plt.show()

# %%
df_2['airport_interaction'] = df_2['Airport_Name_dep']+'-'+df_2['Airport_Name_arr']

# %% [markdown]
# Antes de evaluar cada caso en particular, es importante verificar como se distribuyen estaas rutas año a año. Aqui podemos encontrar entonces que las rutas dentro de Brazil siempre han tenido un distribución similar entre años mientras que, considerando los meses de pandemia, el mercado Brazil - Chile y Brazil - Colombia ha tenido o potencial a crecer.

# %%
df_bb = df_2[(df_2['country_interaction'] == 'BRAZIL-BRAZIL') & (df_2['año'] > 2019)]
df_bco = df_2[(df_2['country_interaction'] == 'BRAZIL-COLOMBIA') & (df_2['año'] > 2019)]
df_bch = df_2[(df_2['country_interaction'] == 'BRAZIL-CHILE') & (df_2['año'] > 2019)]

# %%
df_bb_top = df_bb[['airport_interaction', 'año', 'mes', 'count']]
df_bb_top = df_bb_top.groupby(by=['airport_interaction', 'año', 'mes']).count().reset_index()

df_bb_top = df_bb_top.sort_values(by=['año', 'count'], ascending=False)

df_bb_top = df_bb_top.set_index(['airport_interaction']).groupby(['mes', 'año'])['count'].nlargest(1).reset_index()

df_bb_top = df_bb_top.groupby('airport_interaction')['count'].sum()
df_bb_top
# Out:
# airport_interaction
# Eduardo Gomes Intl-Guarulhos Intl             87
# Guararapes Intl-Guarulhos Intl                66
# Guararapes Intl-Viracopos-Campinas Int       117
# Guarulhos Intl-Eduardo Gomes Intl             37
# Pinto Martins Intl-Viracopos-Campinas Int     21
# Name: count, dtype: int64

# %%
df_bco_top = df_bco[['airport_interaction', 'año', 'mes', 'count']]
df_bco_top = df_bco_top.groupby(by=['airport_interaction', 'año', 'mes']).count().reset_index()

df_bco_top = df_bco_top.sort_values(by=['año', 'count'], ascending=False)

df_bco_top = df_bco_top.set_index(['airport_interaction']).groupby(['mes', 'año'])['count'].nlargest(1).reset_index()

df_bco_top = df_bco_top.groupby('airport_interaction')['count'].sum()
df_bco_top
# Out:
# airport_interaction
# Guarulhos Intl-El Dorado Intl             84
# Viracopos-Campinas Int-El Dorado Intl    125
# Name: count, dtype: int64

# %%
df_bch_top = df_bch[['airport_interaction', 'año', 'mes', 'count']]
df_bch_top = df_bch_top.groupby(by=['airport_interaction', 'año', 'mes']).count().reset_index()

df_bch_top = df_bch_top.sort_values(by=['año', 'count'], ascending=False)

df_bch_top = df_bch_top.set_index(['airport_interaction']).groupby(['mes', 'año'])['count'].nlargest(1).reset_index()

df_bch_top = df_bch_top.groupby('airport_interaction')['count'].sum()
df_bch_top
# Out:
# airport_interaction
# Guarulhos Intl-Arturo Merino Benitez            320
# Viracopos-Campinas Int-Arturo Merino Benitez      5
# Name: count, dtype: int64

# %% [markdown]
# Las rutas con mayor frecuencia escogidas son:
# - Dentro de Brazil Guararapes Intl-Viracopos-Campinas Int
# - Entre Brazil y Colombia Viracopos-Campinas Int-El Dorado Intl
# - entre Brazil y Chile Guarulhos Intl-Arturo Merino Benitez

# %%
df_final = df_2[(df_2['airport_interaction']=='Guararapes Intl-Viracopos-Campinas Int') | (df_2['airport_interaction']=='Viracopos-Campinas Int-El Dorado Intl') | (df_2['airport_interaction']=='Guarulhos Intl-Arturo Merino Benitez')]

# %%
df_final_peso = df_final[['airport_interaction', 'mes', 'año', 'weight_kg']]
df_final_peso = df_final.groupby(by=['airport_interaction', 'año', 'mes'])['weight_kg'].mean().reset_index()

df_final_peso['weight_kg'] = df_final_peso['weight_kg'].astype(int)
df_final_peso['mes'] = df_final_peso['mes'].astype(str)

# %%
df_final_peso_2020 = df_final_peso[df_final_peso['año'] == 2020]
df_final_peso_2021 = df_final_peso[df_final_peso['año'] == 2021]

# %%
df_final_peso.dtypes
# Out:
# airport_interaction    object
# año                     int64
# mes                    object
# weight_kg               int32
# dtype: object

# %%
df_final = df_final[df_final['año']>2019]
df_final_avion = df_final[['aircraft_type', 'airport_interaction', 'mes', 'año', 'count']]
df_final_avion = df_final_avion.groupby(by=['aircraft_type', 'año', 'mes', 'airport_interaction']).count().reset_index()


df_final_avion= df_final_avion.sort_values(by=['año', 'count'], ascending=False)
df_final_avion = df_final_avion.set_index(['aircraft_type']).groupby(['airport_interaction', 'mes', 'año'])['count'].nlargest(1).reset_index()

# %%
df_final_avion_2020 = df_final_avion[df_final_avion['año'] == 2020]
df_final_avion_2021 = df_final_avion[df_final_avion['año'] == 2021]

# %%
fig = plt.figure(figsize=(15,15))
fig.subplots_adjust(hspace=0.4, wspace=0.2)
ax=fig.add_subplot(2,2,1)
sns.lineplot(x='mes', y='weight_kg', hue='airport_interaction', data=df_final_peso_2020).set(title='Relación peso promedio por ruta por mes 2020')
locs, labels = plt.xticks()
ax=fig.add_subplot(2,2,2)
sns.lineplot(x='mes', y='weight_kg', hue='airport_interaction', data=df_final_peso_2021).set(title='Relación peso promedio por ruta por mes 2021')
locs, labels = plt.xticks()
ax=fig.add_subplot(2,2,3)
sns.barplot(x='aircraft_type', y='count', hue='año', data=df_final_avion, ci=None).set(title='Top aviones en rutas foto por año')
locs, labels = plt.xticks()
ax=fig.add_subplot(2,2,4)
sns.barplot(x='mes', y='count', hue='aircraft_type', data=df_final_avion_2021, ci=None).set(title='Top aviones en rutas foto por mes 2021')
locs, labels = plt.xticks()
plt.show()

# %% [markdown]
# Entre las tres rutas seleccionadas para analizar se pueden concluir lo siguientes resultados:
#
# - Entre Brazil y Chile la ruta Guarulhos Intl-Arturo Merino Benitez en el 2021 presentó un pico de eficiencia (mejor peso promedio por viaje) en el mes de junio. Mucha mayor eficiencia incluso que en cualquier mes del 2020. Esto muestra una oportunidad de mejora que debería analizarce más a fondo.
# - La ruta dentro de Brazil Guararapes Intl-Viracopos-Campinas Int tiene una capacidad que fluctua mucho de mes a mes y siendo aquella que tiene mayor frecuencia podría tener una oportunidad para analizar el negocio y buscar estabilizar cuan eficiente es y obtener más rendimientos.
# - El target de eficiencia debería ser tomado la ruta entre Brazil y Colombia Viracopos-Campinas Int-El Dorado Intl, es una ruta con una eficiencia alta y presenta poca variación. Es claro que las relaciones entre Colombia, Brazil y Avianca son bastante fuertes. Este tipo de relaciones se deben empezar a construir para poder llegar a la misma linea de eficiencia entre las rutas más frecuentes.
# - Evaluando los tipos de aeronaves que más an participado entre estas 3 rutas la A330 ha sido la aerolinea insignia. se recomienda buscar mayor participación de esta aeronaves o similares pues han presentado buenos resultados.
# - Debido al corto tiempo, aunque no es posible analizar la eficiencia de carga de las aeronaves con mayor frecuencia, si es el caso se recomienda evaluar entre estas y otras rutas la eficiencia de estas aeronaves y así continuar encontrando insights para futuras aplicaciones.
# - La participación de la operación es fundamental, entender porque hay rutas donde la fluctuación de la eficiencia llama la atención es una buena oportunidad para relacionar tanto el departamento de gestión como los departamentos operativos.
# - A pesar de todos los problemas generados por la emergencia sanitaria, la recuperación de Avianca se evidencia en la región. mantener esta tendencia y buscar aquellos rendimientos escondidos en la data puede permitir de nuevo el crecimiento de la compañía hacía y desde otras regiones.
